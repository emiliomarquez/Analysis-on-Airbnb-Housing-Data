# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import HeatMap
from IPython.display import HTML
import matplotlib.pyplot as plt
# %matplotlib inline
import json

# %% [markdown]
# # Restaurant Inspection Scores

# %%
#Read in csv file with Restaurant Inspection Scores
scores = pd.read_csv('data/restaurant_inspec_scores.csv')

# %%
#For now, only use restaurants that have latitude/longitude
scores_lat = scores[scores['business_latitude'].notnull()]
scores_lat
# Out:
#        business_id                 business_name     business_address  \
# 22            3196  United Irish Cultural Center        2700 45th Ave
# 33            5827   HILLCREST ELEMENTARY SCHOOL       810 SILVER Ave
# 63            5959          ST. JOHN'S SNACK BAR       925 CHENERY St
# 89            1231               Yamo Restaurant         3406 18th St
# 114          68451                Buckhorn Grill    101 04th St #1060
# ...            ...                           ...                  ...
# 53850         7643          PACIFIC SUPER MARKET    2900 ALEMANY Blvd
# 53851        60473   Dong Baek Korean Restaurant     631 O'Farrell St
# 53852         1843           Ma's Dim Sum & Cafe       1315 Powell St
# 53853        11365           LE PETITT'S KITCHEN  265 GOLDEN GATE AVE
# 53854        65057                   The Brixton        2140 UNION St
#
#        business_city business_state business_postal_code  business_latitude  \
# 22     San Francisco             CA                94116          37.735943
# 33     San Francisco             CA                94134          37.729016
# 63     San Francisco             CA                94131          37.735264
# 89     San Francisco             CA                94110          37.761882
# 114    San Francisco             CA                94103          37.784548
# ...              ...            ...                  ...                ...
# 53850  San Francisco             CA                94112          37.712148
# 53851  San Francisco             CA                94109          37.785503
# 53852  San Francisco             CA                94133          37.796683
# 53853  San Francisco             CA                94109          37.781690
# 53854  San Francisco             CA                94123          37.797238
#
#        business_longitude              business_location  \
# 22            -122.503086  POINT (-122.503086 37.735943)
# 33            -122.419253  POINT (-122.419253 37.729016)
# 63            -122.437679  POINT (-122.437679 37.735264)
# 89            -122.419599  POINT (-122.419599 37.761882)
# 114           -122.404190   POINT (-122.40419 37.784548)
# ...                   ...                            ...
# 53850         -122.452076  POINT (-122.452076 37.712148)
# 53851         -122.415157  POINT (-122.415157 37.785503)
# 53852         -122.410134  POINT (-122.410134 37.796683)
# 53853         -122.414823   POINT (-122.414823 37.78169)
# 53854         -122.434533  POINT (-122.434533 37.797238)
#
#        business_phone_number   inspection_id  inspection_date  \
# 22                       NaN   3196_20170201    2/1/2017 0:00
# 33              1.415546e+10   5827_20190903    9/3/2019 0:00
# 63              1.415559e+10   5959_20180403    4/3/2018 0:00
# 89                       NaN   1231_20190904    9/4/2019 0:00
# 114                      NaN  68451_20180226   2/26/2018 0:00
# ...                      ...             ...              ...
# 53850           1.415533e+10   7643_20161101   11/1/2016 0:00
# 53851                    NaN  60473_20190228   2/28/2019 0:00
# 53852                    NaN   1843_20171129  11/29/2017 0:00
# 53853                    NaN  11365_20170216   2/16/2017 0:00
# 53854           1.415540e+10  65057_20170705    7/5/2017 0:00
#
#        inspection_score        inspection_type           violation_id  \
# 22                  NaN  Reinspection/Followup                    NaN
# 33                 88.0  Routine - Unscheduled   5827_20190903_103120
# 63                100.0  Routine - Unscheduled                    NaN
# 89                  NaN       New Construction                    NaN
# 114                74.0  Routine - Unscheduled  68451_20180226_103119
# ...                 ...                    ...                    ...
# 53850               NaN              Complaint                    NaN
# 53851              79.0  Routine - Unscheduled  60473_20190228_103109
# 53852               NaN  Reinspection/Followup                    NaN
# 53853              96.0  Routine - Unscheduled  11365_20170216_103119
# 53854              80.0  Routine - Unscheduled  65057_20170705_103105
#
#                                    violation_description  risk_category
# 22                                                   NaN            NaN
# 33                Moderate risk food holding temperature  Moderate Risk
# 63                                                   NaN            NaN
# 89                                                   NaN            NaN
# 114    Inadequate and inaccessible handwashing facili...  Moderate Risk
# ...                                                  ...            ...
# 53850                                                NaN            NaN
# 53851        Unclean or unsanitary food contact surfaces      High Risk
# 53852                                                NaN            NaN
# 53853  Inadequate and inaccessible handwashing facili...  Moderate Risk
# 53854                           Improper cooling methods      High Risk
#
# [27475 rows x 17 columns]

# %% [markdown]
# # Airbnb Listings

# %%
#Read in csv file with Airbnb data
airbnb = pd.read_csv('data/sf_airbnb_listings.csv')

# %% [markdown]
# # SF Map with Airbnb HeatMap

# %%
sf_coord = [37.76, -122.45] #Coordination of city of San Francisco

#Set up basic map of San Francisco
sf_map = folium.Map(location=sf_coord,
                    tiles='cartodbpositron',
                    zoom_start=12.5)

# %%
#Add a heat map based on data in Airbnb table to the San Francisco map
HeatMap(data=airbnb[['latitude', 'longitude']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(sf_map)
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Add Inspec Risk Data to SF Map

# %%
#Color dictionary per risk factor
colordict = {'High Risk': 'red', 'Moderate Risk': 'yellow', 'Low Risk': 'green'}

#Add restaurant data with different colors based on the risk factor
for lat, lon, risk, name in zip(scores_lat['business_latitude'], scores_lat['business_longitude'], scores_lat['risk_category'], scores_lat['business_name']):
    if risk in ['High Risk', 'Moderate Risk', 'Low Risk']:
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            color='b',
            fill_color=colordict[risk],
            fill=True,
            fill_opacity=1
            ).add_to(sf_map)

# %%
#Save the map into a callable html file (This is how to save time and not cause an error in loading lots of data)
sf_map.save('sf_data_visualization.html')

# %%
#Import Folium interactive html file
HTML('<iframe src=sf_data_visualization.html width=1000 height=700></iframe>')
# Out:
# <iframe src=sf_data_visualization.html width=1000 height=700></iframe>

# %% [markdown]
# # Airbnb with \# of nearby restaurants

# %%
a_w_rest = pd.read_csv('airbnb_with_#of_restuarants.csv')

# %%
sf_coord = [37.76, -122.45] #Coordination of city of San Francisco

#Set up basic map of San Francisco
sf_map_2 = folium.Map(location=sf_coord,
                    tiles='cartodbpositron',
                    zoom_start=12.5)

# %%
for lat, lon, num in zip(a_w_rest['latitude'], a_w_rest['longitude'], a_w_rest['rest_num']):
    folium.Circle(
        [lat, lon],
        radius=num,
        color='b',
        fill_color='crimson',
        fill=True,
        ).add_to(sf_map_2)

# %%
sf_map_2.save('trying_this.html')

# %%
HTML('<iframe src=trying_this.html width=1000 height=700></iframe>')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=trying_this.html width=1000 height=700></iframe>

# %% [markdown]
# # Processed data with score and location

# %%
df = pd.read_csv('data/processed.csv')

# %%
df = df[df['inspection_score'].notnull()]

# %% [markdown]
# # Categorize score based on SF data
# - above 90: good
# - 86-90: adequate
# - 71-85: needs improvement
# - <= 70: poor

# %%
def categorize_score (score):
    if (score > 90):
        return 'Good'
    elif (score >= 86) & (score <= 90):
        return 'Adequate'
    elif (score >= 71) & (score <= 85):
        return 'Needs improvement'
    elif (score <= 70):
        return 'Poor'

# %%
df['scores'] = df['inspection_score'].apply(categorize_score)

# %% [markdown]
# # SF Map with categorized score colors

# %%
sf_coord = [37.76, -122.45] #Coordination of city of San Francisco

#Set up basic map of San Francisco
sf_map_3 = folium.Map(location=sf_coord,
                    tiles='cartodbpositron',
                    zoom_start=12.5)

# %%
#Color dictionary per risk factor
colordict = {'Poor': 'red', 'Needs improvement': 'orange', 'Adequate': 'yellow', 'Good': 'green'}

#Add restaurant data with different colors based on the risk factor
for lat, lon, score in zip(df['business_latitude'], df['business_longitude'], df['scores']):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        color='b',
        fill_color=colordict[score],
        fill=True,
        fill_opacity=1
        ).add_to(sf_map_3)

# %%
sf_map_3.save('inspect_score.html')

# %%
HTML('<iframe src=inspect_score.html width=1000 height=700></iframe>')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=inspect_score.html width=1000 height=700></iframe>

# %% [markdown]
# # SF Map with categorized score colors and Stamen Toner

# %%
sf_coord = [37.76, -122.45] #Coordination of city of San Francisco

#Set up basic map of San Francisco
sf_toner = folium.Map(location=sf_coord,
                    tiles='Stamen Toner',
                    zoom_start=12.5)

# %%
#Color dictionary per risk factor
colordict = {'Poor': 'red', 'Needs improvement': 'orange', 'Adequate': 'yellow', 'Good': 'green'}

#Add restaurant data with different colors based on the risk factor
for lat, lon, score in zip(df['business_latitude'], df['business_longitude'], df['scores']):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        color='b',
        fill_color=colordict[score],
        fill=True,
        fill_opacity=1
        ).add_to(sf_toner)

# %%
HeatMap(data=airbnb[['latitude', 'longitude']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(sf_toner)

# %%
sf_toner.save('inspect_score_toner.html')

# %%
HTML('<iframe src=inspect_score_toner.html width=1000 height=700></iframe>')
# Out:
# <iframe src=inspect_score_toner.html width=1000 height=700></iframe>

# %% [markdown]
# # Airbnb with only good restaurants

# %%
sf_coord = [37.76, -122.45] #Coordination of city of San Francisco

#Set up basic map of San Francisco
sf_toner_2 = folium.Map(location=sf_coord,
                    tiles='Stamen Toner',
                    zoom_start=12.5)

# %%
#Add restaurant data with different colors based on the risk factor
for lat, lon, score in zip(df['business_latitude'], df['business_longitude'], df['scores']):
    if score == 'Good':
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            color='b',
            fill_color='green',
            fill=True,
            fill_opacity=1
            ).add_to(sf_toner_2)

# %%
HeatMap(data=airbnb[['latitude', 'longitude']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(sf_toner_2)

# %%
sf_toner_2.save('inspect_score_toner_good.html')

# %%
HTML('<iframe src=inspect_score_toner_good.html width=1000 height=700></iframe>')
# Out:
# <iframe src=inspect_score_toner_good.html width=1000 height=700></iframe>

# %%
listing = pd.read_csv('data/listings.csv')
listing
# Out:
#             id                                               name    host_id  \
# 0          958                Bright, Modern Garden Unit - 1BR/1B       1169
# 1         3850                              Charming room for two       4921
# 2         5858                                 Creative Sanctuary       8904
# 3         7918         A Friendly Room - UCSF/USF - San Francisco      21994
# 4         8142  Friendly Room Apt. Style -UCSF/USF - San Franc...      21994
# ...        ...                                                ...        ...
# 8528  40544136  Entire apartment in Pacific Heights/beautiful ...   39425074
# 8529  40546145        Huge Private Room; 8 min to Dwntwn SF & SFO  313682675
# 8530  40547706              Welcome onboard a beautiful Sailboat!   10994095
# 8531  40560328  Lg 1 Bed/1 Bath w/ Living & Dining Rm in Top Area   24087059
# 8532  40569280  Clean Spacious Room in Central SF Flat - 30 Da...    4856574
#
#              host_name  neighbourhood_group        neighbourhood  latitude  \
# 0                Holly                  NaN     Western Addition  37.76931
# 1                Kevin                  NaN         Inner Sunset  37.75402
# 2     Philip And Tania                  NaN       Bernal Heights  37.74511
# 3                Aaron                  NaN       Haight Ashbury  37.76669
# 4                Aaron                  NaN       Haight Ashbury  37.76487
# ...                ...                  ...                  ...       ...
# 8528               Sam                  NaN      Pacific Heights  37.79017
# 8529            Connor                  NaN              Bayview  37.71977
# 8530             Aline                  NaN  Treasure Island/YBI  37.81704
# 8531             Simon                  NaN      Pacific Heights  37.79179
# 8532              Jeff                  NaN              Mission  37.75857
#
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0    -122.43386  Entire home/apt    170               1                226
# 1    -122.45805     Private room     99               1                175
# 2    -122.42102  Entire home/apt    235              30                111
# 3    -122.45250     Private room     65              32                 18
# 4    -122.45183     Private room     65              32                  8
# ...         ...              ...    ...             ...                ...
# 8528 -122.43869  Entire home/apt     95              30                  0
# 8529 -122.39214     Private room     55               1                  0
# 8530 -122.36999  Entire home/apt    100              30                  0
# 8531 -122.43021  Entire home/apt    295               2                  0
# 8532 -122.41479     Private room     60              30                  0
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# 0     2019-11-17               1.79                               1
# 1     2019-12-01               1.38                               3
# 2     2017-08-06               0.86                               1
# 3     2019-09-10               0.14                               9
# 4     2018-09-12               0.13                               9
# ...          ...                ...                             ...
# 8528         NaN                NaN                               2
# 8529         NaN                NaN                               2
# 8530         NaN                NaN                               1
# 8531         NaN                NaN                               2
# 8532         NaN                NaN                               8
#
#       availability_365
# 0                   71
# 1                   74
# 2                    1
# 3                  365
# 4                  365
# ...                ...
# 8528               337
# 8529                59
# 8530               173
# 8531                 4
# 8532                52
#
# [8533 rows x 16 columns]

# %% [markdown]
# # Choropleth Map based on average cost per neighbourhood

# %%
avg_listing = listing[['neighbourhood','price']].groupby('neighbourhood').mean().reset_index()

# %%
san_fran_geo = 'san-francisco.geojson'

# %%
sf_coord = [37.76, -122.45] #Coordination of city of San Francisco

#Set up basic map of San Francisco
sf_choro = folium.Map(location=sf_coord,
                    tiles='cartodbpositron',
                    zoom_start=12.5)

# %%
folium.Choropleth(
    geo_data=san_fran_geo,
    name='choropleth',
    data=avg_listing,
    columns=['neighbourhood', 'price'],
    key_on='feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Average Airbnb Price ($)'
).add_to(sf_choro)

#Save to html
sf_choro.save('choropleth_sf.html')

# %%
HTML('<iframe src=choropleth_sf.html width=900 height=700></iframe>')
# Out:
# <iframe src=choropleth_sf.html width=900 height=700></iframe>
